# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#              Date      Symbol Underlying Close Price (A)  \
# 0     30-JUL-2021   20MICRONS                      66.70
# 1     30-JUL-2021  21STCENMGM                      22.55
# 2     30-JUL-2021  3IINFOTECH                       9.30
# 3     30-JUL-2021     3MINDIA                   24661.00
# 4     30-JUL-2021      3PLAND                      16.20
# ...           ...         ...                        ...
# 4086  30-JUL-2021       SWATI                          -
# 4087  30-JUL-2021  TECHAINPOW                          -
# 4088  30-JUL-2021    TIRUPATI                          -
# 4089  30-JUL-2021        TLFL                          -
# 4090  30-JUL-2021  TRANSGLOBE                          -
#
#      Underlying Previous Day Close Price (B)  \
# 0                                      64.20
# 1                                      22.20
# 2                                       9.40
# 3                                   24841.50
# 4                                      16.05
# ...

# %%
print((df.Symbol).dtype)
# Out:
# object

# %%
print((df.Date).dtype)
# Out:
# object
